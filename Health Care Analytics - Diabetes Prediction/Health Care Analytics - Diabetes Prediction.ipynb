# %%
import pandas as pd

labs_df = pd.read_csv("../Data/diabetes/labs.csv")
diet_df = pd.read_csv("../Data/diabetes/diet.csv")
examination_df = pd.read_csv("../Data/diabetes/examination.csv")
demographic_df = pd.read_csv("../Data/diabetes/demographic.csv")
questionnaire_df = pd.read_csv("../Data/diabetes/questionnaire.csv")

# %%
labs_df.head()
# Out:
#     SEQN  URXUMA  URXUMS  URXUCR.x   URXCRS  URDACT     WTSAF2YR.x  LBXAPB  \
# 0  73557     4.3     4.3      39.0   3447.6   11.03            NaN     NaN
# 1  73558   153.0   153.0      50.0   4420.0  306.00            NaN     NaN
# 2  73559    11.9    11.9     113.0   9989.2   10.53  142196.890197    57.0
# 3  73560    16.0    16.0      76.0   6718.4   21.05            NaN     NaN
# 4  73561   255.0   255.0     147.0  12994.8  173.47  142266.006548    92.0
#
#    LBDAPBSI  LBXSAL  ...  URXUTL  URDUTLLC  URXUTU  URDUTULC  URXUUR  \
# 0       NaN     4.1  ...     NaN       NaN     NaN       NaN     NaN
# 1       NaN     4.7  ...     NaN       NaN     NaN       NaN     NaN
# 2      0.57     3.7  ...     NaN       NaN     NaN       NaN     NaN
# 3       NaN     NaN  ...   0.062       0.0   0.238       0.0  0.0071
# 4      0.92     4.3  ...     NaN       NaN     NaN       NaN     NaN
#
#    URDUURLC  URXPREG  URXUAS  LBDB12  LBDB12SI
# 0       NaN      NaN     NaN   524.0     386.7
# ...

# %%
diet_df.head()
# Out:
#     SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0  73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1  73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2  73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3  73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4  73561   59052.357033   39004.892993         1      63.0    2.0     2.0
#
#    DR1DBIH  DR1DAY  DR1LANG  ...  DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0      6.0     2.0      1.0  ...       NaN      NaN       NaN      NaN
# 1      4.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
# 2     18.0     6.0      1.0  ...       NaN      NaN       NaN      NaN
# 3     21.0     3.0      1.0  ...       NaN      NaN       NaN      NaN
# 4     18.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
#
#    DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# ...

# %%
examination_df.head()
# Out:
#     SEQN  PEASCST1  PEASCTM1  PEASCCT1  BPXCHR  BPAARM  BPACSZ  BPXPLS  \
# 0  73557         1     620.0       NaN     NaN     1.0     4.0    86.0
# 1  73558         1     766.0       NaN     NaN     1.0     4.0    74.0
# 2  73559         1     665.0       NaN     NaN     1.0     4.0    68.0
# 3  73560         1     803.0       NaN     NaN     1.0     2.0    64.0
# 4  73561         1     949.0       NaN     NaN     1.0     3.0    92.0
#
#    BPXPULS  BPXPTY  ...  CSXLEAOD  CSXSOAOD  CSXGRAOD  CSXONOD  CSXNGSOD  \
# 0      1.0     1.0  ...       2.0       1.0       1.0      1.0       4.0
# 1      1.0     1.0  ...       3.0       1.0       2.0      3.0       4.0
# 2      1.0     1.0  ...       2.0       1.0       2.0      3.0       4.0
# 3      1.0     1.0  ...       NaN       NaN       NaN      NaN       NaN
# 4      1.0     1.0  ...       3.0       1.0       4.0      3.0       4.0
#
#    CSXSLTRT  CSXSLTRG  CSXNART  CSXNARG  CSAEFFRT
# ...

# %%
demographic_df.head()
# Out:
#     SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  73557         8         2         1        69       NaN         4
# 1  73558         8         2         1        54       NaN         3
# 2  73559         8         2         1        72       NaN         3
# 3  73560         8         2         1         9       NaN         3
# 4  73561         8         2         2        73       NaN         3
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0         4       1.0       NaN  ...       3.0       4.0       NaN
# 1         3       1.0       NaN  ...       3.0       1.0       1.0
# 2         3       2.0       NaN  ...       4.0       1.0       3.0
# 3         3       1.0     119.0  ...       3.0       1.0       4.0
# 4         3       1.0       NaN  ...       5.0       1.0       5.0
#
#        WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %%
questionnaire_df.head()
# Out:
#     SEQN  ACD011A  ACD011B  ACD011C  ACD040  ACD110  ALQ101  ALQ110  ALQ120Q  \
# 0  73557      1.0      NaN      NaN     NaN     NaN     1.0     NaN      1.0
# 1  73558      1.0      NaN      NaN     NaN     NaN     1.0     NaN      7.0
# 2  73559      1.0      NaN      NaN     NaN     NaN     1.0     NaN      0.0
# 3  73560      1.0      NaN      NaN     NaN     NaN     NaN     NaN      NaN
# 4  73561      1.0      NaN      NaN     NaN     NaN     1.0     NaN      0.0
#
#    ALQ120U  ...  WHD080U  WHD080L  WHD110  WHD120  WHD130  WHD140  WHQ150  \
# 0      3.0  ...      NaN     40.0   270.0   200.0    69.0   270.0    62.0
# 1      1.0  ...      NaN      NaN   240.0   250.0    72.0   250.0    25.0
# 2      NaN  ...      NaN      NaN   180.0   190.0    70.0   228.0    35.0
# 3      NaN  ...      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 4      NaN  ...      NaN      NaN   150.0   135.0    67.0   170.0    60.0
#
#    WHQ030M  WHQ500  WHQ520
# 0      NaN     NaN     NaN
# ...

# %%
diet_df.drop(columns='SEQN', inplace=True)
examination_df.drop(columns='SEQN', inplace=True)
demographic_df.drop(columns='SEQN', inplace=True)
questionnaire_df.drop(columns='SEQN', inplace=True)

# %%
df = pd.concat([labs_df, diet_df], axis=1, join='inner')
df = pd.concat([df, examination_df], axis=1, join='inner')
df = pd.concat([df, demographic_df], axis=1, join='inner')
df = pd.concat([df, questionnaire_df], axis=1, join='inner')
df.head()
# Out:
#     SEQN  URXUMA  URXUMS  URXUCR.x   URXCRS  URDACT     WTSAF2YR.x  LBXAPB  \
# 0  73557     4.3     4.3      39.0   3447.6   11.03            NaN     NaN
# 1  73558   153.0   153.0      50.0   4420.0  306.00            NaN     NaN
# 2  73559    11.9    11.9     113.0   9989.2   10.53  142196.890197    57.0
# 3  73560    16.0    16.0      76.0   6718.4   21.05            NaN     NaN
# 4  73561   255.0   255.0     147.0  12994.8  173.47  142266.006548    92.0
#
#    LBDAPBSI  LBXSAL  ...  WHD080U  WHD080L  WHD110  WHD120  WHD130  WHD140  \
# 0       NaN     4.1  ...      NaN     40.0   270.0   200.0    69.0   270.0
# 1       NaN     4.7  ...      NaN      NaN   240.0   250.0    72.0   250.0
# 2      0.57     3.7  ...      NaN      NaN   180.0   190.0    70.0   228.0
# 3       NaN     NaN  ...      NaN      NaN     NaN     NaN     NaN     NaN
# 4      0.92     4.3  ...      NaN      NaN   150.0   135.0    67.0   170.0
#
#    WHQ150  WHQ030M  WHQ500  WHQ520
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9813 entries, 0 to 9812
# Columns: 1812 entries, SEQN to WHQ520
# dtypes: float64(1753), int64(28), object(31)
# memory usage: 135.7+ MB

# %%
df.dropna(axis=0, how='all', inplace=True)
df.dropna(axis=1, how='all', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9813 entries, 0 to 9812
# Columns: 1806 entries, SEQN to WHQ520
# dtypes: float64(1747), int64(28), object(31)
# memory usage: 135.3+ MB

# %% [markdown]
# According to Glycohemoglobin, 0-> Normal status 1-> High-risk diabetes 2-> Diabetes patients

# %%
df = df.rename(columns={'SEQN' : 'ID',
                        'RIAGENDR' : 'Gender',
                        'DMDYRSUS' : 'Years_in_US',
                        'INDFMPIR' : 'Family_income',
                        'LBXGH' : 'GlycoHemoglobin',
                        'BMXARMC' : 'ArmCircum',
                        'BMDAVSAD' : 'SaggitalAbdominal',
                        'MGDCGSZ' : 'GripStrength',
                        'DRABF' : 'Breast_fed'})

df = df.loc[:, ['ID', 'Gender', 'Years_in_US', 'Family_income','GlycoHemoglobin', 'ArmCircum',  'SaggitalAbdominal', 
                'GripStrength', 'Breast_fed']]

df.describe()
# Out:
#                  ID       Gender  Years_in_US  Family_income  GlycoHemoglobin  \
# count   9813.000000  9813.000000  1837.000000    9051.000000      6643.000000
# mean   78644.559971     1.509426     8.933043       2.253101         5.642556
# std     2938.592266     0.499937    17.787060       1.635458         1.004850
# min    73557.000000     1.000000     1.000000       0.000000         3.500000
# 25%    76092.000000     1.000000     3.000000       0.870000         5.200000
# 50%    78643.000000     2.000000     5.000000       1.710000         5.400000
# 75%    81191.000000     2.000000     7.000000       3.610000         5.800000
# max    83731.000000     2.000000    99.000000       5.000000        17.500000
#
#          ArmCircum  SaggitalAbdominal  GripStrength   Breast_fed
# count  9301.000000        7218.000000   7677.000000  8661.000000
# mean     28.485765          21.114034     63.054891     1.984528
# std       7.961971           4.963949     25.098439     0.123426
# ...

# %%
df.isnull()
# Out:
#          ID  Gender  Years_in_US  Family_income  GlycoHemoglobin  ArmCircum  \
# 0     False   False         True          False            False      False
# 1     False   False         True          False            False      False
# 2     False   False         True          False            False      False
# 3     False   False         True          False             True      False
# 4     False   False         True          False            False      False
# ...     ...     ...          ...            ...              ...        ...
# 9808  False   False        False          False            False      False
# 9809  False   False         True          False             True      False
# 9810  False   False         True          False            False      False
# 9811  False   False        False          False             True      False
# 9812  False   False         True          False             True      False
#
#       SaggitalAbdominal  GripStrength  Breast_fed
# ...

# %%
df['Years_in_US'] = df['Years_in_US'].apply(lambda x: x if x > 0 else 0)

df['GlycoHemoglobin'] = df['GlycoHemoglobin'].fillna(df['GlycoHemoglobin'].median())
df['SaggitalAbdominal'] = df['SaggitalAbdominal'].fillna(df['SaggitalAbdominal'].median())
df['ArmCircum'] = df['ArmCircum'].fillna(df['ArmCircum'].median())
df['GripStrength'] = df['GripStrength'].fillna(df['GripStrength'].median())

df['Family_income'] = df['Family_income'].fillna(method='ffill')

df['Breast_fed'] = df['Breast_fed'].fillna(value = 1)

df.describe()
# Out:
#                  ID       Gender  Years_in_US  Family_income  GlycoHemoglobin  \
# count   9813.000000  9813.000000  9813.000000    9813.000000      9813.000000
# mean   78644.559971     1.509426     1.672271       2.246973         5.564201
# std     2938.592266     0.499937     8.446506       1.635495         0.834491
# min    73557.000000     1.000000     0.000000       0.000000         3.500000
# 25%    76092.000000     1.000000     0.000000       0.870000         5.300000
# 50%    78643.000000     2.000000     0.000000       1.700000         5.400000
# 75%    81191.000000     2.000000     0.000000       3.600000         5.600000
# max    83731.000000     2.000000    99.000000       5.000000        17.500000
#
#          ArmCircum  SaggitalAbdominal  GripStrength   Breast_fed
# count  9813.000000        9813.000000   9813.000000  9813.000000
# mean     28.528248          21.004545     62.455233     1.868949
# std       7.753571           4.261142     22.228196     0.337473
# ...

# %%
df.loc[df['GlycoHemoglobin'] < 6.0, 'Diabetes'] = 0
df.loc[(df['GlycoHemoglobin'] >= 6.0) & (df['GlycoHemoglobin'] <= 6.4), 'Diabetes'] = 1
df.loc[df['GlycoHemoglobin'] >= 6.5, 'Diabetes'] = 2

df.head(10)
# Out:
#       ID  Gender  Years_in_US  Family_income  GlycoHemoglobin  ArmCircum  \
# 0  73557       1          0.0           0.84             13.9       35.3
# 1  73558       1          0.0           1.78              9.1       34.7
# 2  73559       1          0.0           4.51              8.9       33.5
# 3  73560       1          0.0           2.52              5.4       21.0
# 4  73561       2          0.0           5.00              4.9       25.2
# 5  73562       1          0.0           4.79              5.5       41.8
# 6  73563       1          0.0           5.00              5.4       14.9
# 7  73564       2          0.0           5.00              5.5       38.0
# 8  73566       1          0.0           5.00              5.4       29.0
# 9  73567       2          0.0           0.48              5.2       27.5
#
#    SaggitalAbdominal  GripStrength  Breast_fed  Diabetes
# 0               20.6          55.2         2.0       2.0
# ...

# %%
df.drop(['GlycoHemoglobin'], axis=1, inplace=True)
df.head(5)
# Out:
#       ID  Gender  Years_in_US  Family_income  ArmCircum  SaggitalAbdominal  \
# 0  73557       1          0.0           0.84       35.3               20.6
# 1  73558       1          0.0           1.78       34.7               24.4
# 2  73559       1          0.0           4.51       33.5               25.6
# 3  73560       1          0.0           2.52       21.0               14.9
# 4  73561       2          0.0           5.00       25.2               20.7
#
#    GripStrength  Breast_fed  Diabetes
# 0          55.2         2.0       2.0
# 1          61.5         2.0       2.0
# 2          91.0         2.0       2.0
# 3          32.2         2.0       0.0
# 4          30.9         2.0       0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colormap = plt.cm.viridis
plt.figure(figsize=(15, 10))
sns.heatmap(df.astype(float).drop(axis=1, labels='ID').corr(), linewidths=0.1, vmax=1.0, square=True, 
            cmap=colormap, annot=True)

# %%
df['Diabetes'].value_counts()
# Out:
# 0.0    8622
# 2.0     604
# 1.0     587
# Name: Diabetes, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x = df.iloc[:, 4:].drop(['Diabetes'], axis=1)
y = df.iloc[:, 8].to_frame()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=500)
forest.fit(x_train, y_train)
res = forest.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, res)
# Out:
# array([[1699,   11,   22],
#        [ 110,    3,    8],
#        [  95,    5,   10]], dtype=int64)

# %% [markdown]
# 0-> Normal status 1-> High-risk diabetes 2-> Diabetes patients

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_boost = AdaBoostClassifier(n_estimators=500)
ada_boost.fit(x_train, y_train)
res = ada_boost.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
confusion_matrix(y_test, res)
# Out:
# array([[1719,    1,   12],
#        [ 116,    0,    5],
#        [ 101,    2,    7]], dtype=int64)

# %%
x = df.loc[:, ['ArmCircum', 'SaggitalAbdominal']]
y = df.iloc[:, 8].to_frame()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)

# %%
forest.fit(x_train, y_train)
res = forest.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
confusion_matrix(y_test, res)
# Out:
# array([[1646,   38,   48],
#        [ 103,    6,   12],
#        [  94,    7,    9]], dtype=int64)

# %%
df.head()
# Out:
#       ID  Gender  Years_in_US  Family_income  ArmCircum  SaggitalAbdominal  \
# 0  73557       1          0.0           0.84       35.3               20.6
# 1  73558       1          0.0           1.78       34.7               24.4
# 2  73559       1          0.0           4.51       33.5               25.6
# 3  73560       1          0.0           2.52       21.0               14.9
# 4  73561       2          0.0           5.00       25.2               20.7
#
#    GripStrength  Breast_fed  Diabetes
# 0          55.2         2.0       2.0
# 1          61.5         2.0       2.0
# 2          91.0         2.0       2.0
# 3          32.2         2.0       0.0
# 4          30.9         2.0       0.0

# %%
x = df.loc[:, ['Gender', 'Years_in_US', 'Family_income', 'GripStrength', 'Breast_fed']]

# %%
x
# Out:
#       Gender  Years_in_US  Family_income  GripStrength  Breast_fed
# 0          1          0.0           0.84          55.2         2.0
# 1          1          0.0           1.78          61.5         2.0
# 2          1          0.0           4.51          91.0         2.0
# 3          1          0.0           2.52          32.2         2.0
# 4          2          0.0           5.00          30.9         2.0
# ...      ...          ...            ...           ...         ...
# 9808       2          4.0           1.25          70.1         2.0
# 9809       1          0.0           1.06          60.3         2.0
# 9810       1          0.0           5.00          46.6         2.0
# 9811       2          3.0           1.53          20.8         1.0
# 9812       2          0.0           3.46          36.0         2.0
#
# [9813 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

k_means = KMeans(n_clusters=3)
k_means.fit_predict(x)
# Out:
# array([2, 2, 1, ..., 0, 0, 0])

# %%
plt.title("Before clustering")
plt.scatter(x.values[:, 2], x.values[:, 3])
plt.show()

plt.title("After clustering")
plt.scatter(x.values[:, 2], x.values[:, 3], c=k_means.labels_)
plt.show()

# %%
for i in range(0, x.shape[0]):
    if k_means.labels_[i] == 1:
        c1 = plt.scatter(x.iloc[i, 2], x.iloc[i, 3], c='r')
    elif k_means.labels_[i] == 0:
        c2 = plt.scatter(x.iloc[i, 2], x.iloc[i, 3], c='g')
    elif k_means.labels_[i] == 2:
        c3 = plt.scatter(x.iloc[i, 2], x.iloc[i, 3], c='b')
        
plt.legend([c1, c2, c3],['High risk', 'Normal', 'Patient'])
plt.show()
